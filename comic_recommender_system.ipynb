# %%
import pandas as pd
import ast
import nltk
from sklearn.neighbors import NearestNeighbors

# %%
df=pd.read_csv("comic_data.csv")

# %%
df
# Out:
#                                                  title  \
# 0                   Salad Days (Tang LiuZang) - Part 2
# 1                              The Master of Diabolism
# 2      JoJo's Bizarre Adventure Part 7: Steel Ball Run
# 3                                  A Sign of Affection
# 4                                 Moriarty the Patriot
# ...                                                ...
# 70943                    Sonna ni Watashi wo Semenaide
# 70944                                Nakitsura ni Kiss
# 70945                                Renjou Lunch Time
# 70946                                101-kaime no Suki
# 70947                               Kirahoshi no Meril
#
#                                              description  rating    year  \
# 0        The second season of Salad Days (Tang LiuZang).     4.7  2021.0
# 1      As the grandmaster who founded the Demonic Sec...     4.7  2017.0
# 2      Set in 1890, Steel Ball Run spotlights Gyro Ze...     4.7  2004.0
# 3      Yuki is a typical college student, whose world...     4.7  2019.0
# 4      Before he was Sherlock’s rival, Moriarty fough...     4.7  2016.0
# ...                                                  ...     ...     ...
# 70943  This entry currently doesn't have a synopsis. ...     NaN  2022.0
# 70944  A clumsy girl and a kind boy have their first ...     NaN  2020.0
# 70945  This entry currently doesn't have a synopsis. ...     NaN  2019.0
# 70946  She's confessed 100 times, what happens on the...     NaN  2020.0
# 70947  This entry currently doesn't have a synopsis. ...     NaN  2019.0
#
#                                                     tags  \
# 0      ['BL', 'Manhua', 'Romance', 'Shounen-ai', 'Spo...
# 1      ['Action', 'Adventure', 'BL', 'Comedy', 'Manhu...
# 2      ['Action', 'Adventure', 'Horror', 'Mystery', '...
# 3      ['Romance', 'Shoujo', 'Slice of Life', 'Disabi...
# 4      ['Mystery', 'Shounen', 'Detectives', 'England'...
# ...                                                  ...
# 70943                              ['Romance', 'Shoujo']
# 70944  ['One Shot', 'Romance', 'Shoujo', 'Slice of Li...
# 70945  ['Comedy', 'One Shot', 'Romance', 'Shounen', '...
# 70946   ['One Shot', 'Romance', 'Shoujo', 'School Life']
# 70947                  ['Action', 'One Shot', 'Shounen']
#
#                                                    cover
# 0      https://cdn.anime-planet.com/manga/primary/sal...
# 1      https://cdn.anime-planet.com/manga/primary/the...
# 2      https://cdn.anime-planet.com/manga/primary/joj...
# 3      https://cdn.anime-planet.com/manga/primary/a-s...
# 4      https://cdn.anime-planet.com/manga/primary/mor...
# ...                                                  ...
# 70943  https://cdn.anime-planet.com/manga/primary/son...
# 70944  https://cdn.anime-planet.com/manga/primary/nak...
# 70945  https://cdn.anime-planet.com/manga/primary/ren...
# 70946  https://cdn.anime-planet.com/manga/primary/101...
# 70947  https://cdn.anime-planet.com/manga/primary/kir...
#
# [70948 rows x 6 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# title              0
# description       31
# rating         41077
# year             824
# tags               0
# cover              0
# dtype: int64

# %%
df.drop(['rating','year'],axis=1,inplace=True)

# %%
df.iloc[1]['cover']
# Out:
# 'https://cdn.anime-planet.com/manga/primary/the-master-of-diabolism-1-190x252.jpg?t=1625917239'

# %%
df.drop('cover',axis=1,inplace=True)

# %%
df
# Out:
#                                                  title  \
# 0                   Salad Days (Tang LiuZang) - Part 2
# 1                              The Master of Diabolism
# 2      JoJo's Bizarre Adventure Part 7: Steel Ball Run
# 3                                  A Sign of Affection
# 4                                 Moriarty the Patriot
# ...                                                ...
# 70943                    Sonna ni Watashi wo Semenaide
# 70944                                Nakitsura ni Kiss
# 70945                                Renjou Lunch Time
# 70946                                101-kaime no Suki
# 70947                               Kirahoshi no Meril
#
#                                              description  \
# 0        The second season of Salad Days (Tang LiuZang).
# 1      As the grandmaster who founded the Demonic Sec...
# 2      Set in 1890, Steel Ball Run spotlights Gyro Ze...
# 3      Yuki is a typical college student, whose world...
# 4      Before he was Sherlock’s rival, Moriarty fough...
# ...                                                  ...
# 70943  This entry currently doesn't have a synopsis. ...
# 70944  A clumsy girl and a kind boy have their first ...
# 70945  This entry currently doesn't have a synopsis. ...
# 70946  She's confessed 100 times, what happens on the...
# 70947  This entry currently doesn't have a synopsis. ...
#
#                                                     tags
# 0      ['BL', 'Manhua', 'Romance', 'Shounen-ai', 'Spo...
# 1      ['Action', 'Adventure', 'BL', 'Comedy', 'Manhu...
# 2      ['Action', 'Adventure', 'Horror', 'Mystery', '...
# 3      ['Romance', 'Shoujo', 'Slice of Life', 'Disabi...
# 4      ['Mystery', 'Shounen', 'Detectives', 'England'...
# ...                                                  ...
# 70943                              ['Romance', 'Shoujo']
# 70944  ['One Shot', 'Romance', 'Shoujo', 'Slice of Li...
# 70945  ['Comedy', 'One Shot', 'Romance', 'Shounen', '...
# 70946   ['One Shot', 'Romance', 'Shoujo', 'School Life']
# 70947                  ['Action', 'One Shot', 'Shounen']
#
# [70948 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# title           0
# description    31
# tags            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# title          0
# description    0
# tags           0
# dtype: int64

# %%
df.iloc[0]['tags']
# Out:
# "['BL', 'Manhua', 'Romance', 'Shounen-ai', 'Sports', 'Webtoons', 'Full Color']"

# %%
def convert(x):
    a=ast.literal_eval(x)
    return a

# %%
df["tags"]=df['tags'].apply(convert)

# %%
df
# Out:
#                                                  title  \
# 0                   Salad Days (Tang LiuZang) - Part 2
# 1                              The Master of Diabolism
# 2      JoJo's Bizarre Adventure Part 7: Steel Ball Run
# 3                                  A Sign of Affection
# 4                                 Moriarty the Patriot
# ...                                                ...
# 70943                    Sonna ni Watashi wo Semenaide
# 70944                                Nakitsura ni Kiss
# 70945                                Renjou Lunch Time
# 70946                                101-kaime no Suki
# 70947                               Kirahoshi no Meril
#
#                                              description  \
# 0        The second season of Salad Days (Tang LiuZang).
# 1      As the grandmaster who founded the Demonic Sec...
# 2      Set in 1890, Steel Ball Run spotlights Gyro Ze...
# 3      Yuki is a typical college student, whose world...
# 4      Before he was Sherlock’s rival, Moriarty fough...
# ...                                                  ...
# 70943  This entry currently doesn't have a synopsis. ...
# 70944  A clumsy girl and a kind boy have their first ...
# 70945  This entry currently doesn't have a synopsis. ...
# 70946  She's confessed 100 times, what happens on the...
# 70947  This entry currently doesn't have a synopsis. ...
#
#                                                     tags
# 0      [BL, Manhua, Romance, Shounen-ai, Sports, Webt...
# 1      [Action, Adventure, BL, Comedy, Manhua, Myster...
# 2      [Action, Adventure, Horror, Mystery, Seinen, 1...
# 3           [Romance, Shoujo, Slice of Life, Disability]
# 4      [Mystery, Shounen, Detectives, England, Europe...
# ...                                                  ...
# 70943                                  [Romance, Shoujo]
# 70944         [One Shot, Romance, Shoujo, Slice of Life]
# 70945  [Comedy, One Shot, Romance, Shounen, Slice of ...
# 70946           [One Shot, Romance, Shoujo, School Life]
# 70947                        [Action, One Shot, Shounen]
#
# [70917 rows x 3 columns]

# %%
df.iloc[1]['description']
# Out:
# 'As the grandmaster who founded the Demonic Sect, Wei WuXian roamed the world in his wanton ways, hated by millions for the chaos he created. In the end, he was back-stabbed by his dearest shidi and killed by powerful clans that combined to overpower him. He incarnates into the body of a lunatic who was abandoned by his clan and is later, unwillingly, taken away by a famous cultivator among the clans—Lan WangJi, his archenemy.'

# %%
df['description']=df['description'].apply(lambda x:x.split())

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(x):
    l=[]
    for i in (x):
        a=ps.stem(i)
        l.append(a)
    return l

# %%
a=df.iloc[0]['tags']
b=stem(a)
b
# Out:
# ['bl', 'manhua', 'romanc', 'shounen-ai', 'sport', 'webtoon', 'full color']

# %%
df['description']=df['description'].apply(stem)

# %%
df['tags']=df['tags'].apply(lambda x:[i.replace(" ","")for i in x])

# %%
df
# Out:
#                                                  title  \
# 0                   Salad Days (Tang LiuZang) - Part 2
# 1                              The Master of Diabolism
# 2      JoJo's Bizarre Adventure Part 7: Steel Ball Run
# 3                                  A Sign of Affection
# 4                                 Moriarty the Patriot
# ...                                                ...
# 70943                    Sonna ni Watashi wo Semenaide
# 70944                                Nakitsura ni Kiss
# 70945                                Renjou Lunch Time
# 70946                                101-kaime no Suki
# 70947                               Kirahoshi no Meril
#
#                                              description  \
# 0      [the, second, season, of, salad, day, (tang, l...
# 1      [as, the, grandmast, who, found, the, demon, s...
# 2      [set, in, 1890,, steel, ball, run, spotlight, ...
# 3      [yuki, is, a, typic, colleg, student,, whose, ...
# 4      [befor, he, wa, sherlock’, rival,, moriarti, f...
# ...                                                  ...
# 70943  [thi, entri, current, doesn't, have, a, synops...
# 70944  [a, clumsi, girl, and, a, kind, boy, have, the...
# 70945  [thi, entri, current, doesn't, have, a, synops...
# 70946  [she', confess, 100, times,, what, happen, on,...
# 70947  [thi, entri, current, doesn't, have, a, synops...
#
#                                                     tags
# 0      [BL, Manhua, Romance, Shounen-ai, Sports, Webt...
# 1      [Action, Adventure, BL, Comedy, Manhua, Myster...
# 2      [Action, Adventure, Horror, Mystery, Seinen, 1...
# 3             [Romance, Shoujo, SliceofLife, Disability]
# 4      [Mystery, Shounen, Detectives, England, Europe...
# ...                                                  ...
# 70943                                  [Romance, Shoujo]
# 70944            [OneShot, Romance, Shoujo, SliceofLife]
# 70945   [Comedy, OneShot, Romance, Shounen, SliceofLife]
# 70946             [OneShot, Romance, Shoujo, SchoolLife]
# 70947                         [Action, OneShot, Shounen]
#
# [70917 rows x 3 columns]

# %%
df['tags']=df['description']+df['tags']

# %%
df
# Out:
#                                                  title  \
# 0                   Salad Days (Tang LiuZang) - Part 2
# 1                              The Master of Diabolism
# 2      JoJo's Bizarre Adventure Part 7: Steel Ball Run
# 3                                  A Sign of Affection
# 4                                 Moriarty the Patriot
# ...                                                ...
# 70943                    Sonna ni Watashi wo Semenaide
# 70944                                Nakitsura ni Kiss
# 70945                                Renjou Lunch Time
# 70946                                101-kaime no Suki
# 70947                               Kirahoshi no Meril
#
#                                              description  \
# 0      [the, second, season, of, salad, day, (tang, l...
# 1      [as, the, grandmast, who, found, the, demon, s...
# 2      [set, in, 1890,, steel, ball, run, spotlight, ...
# 3      [yuki, is, a, typic, colleg, student,, whose, ...
# 4      [befor, he, wa, sherlock’, rival,, moriarti, f...
# ...                                                  ...
# 70943  [thi, entri, current, doesn't, have, a, synops...
# 70944  [a, clumsi, girl, and, a, kind, boy, have, the...
# 70945  [thi, entri, current, doesn't, have, a, synops...
# 70946  [she', confess, 100, times,, what, happen, on,...
# 70947  [thi, entri, current, doesn't, have, a, synops...
#
#                                                     tags
# 0      [the, second, season, of, salad, day, (tang, l...
# 1      [as, the, grandmast, who, found, the, demon, s...
# 2      [set, in, 1890,, steel, ball, run, spotlight, ...
# 3      [yuki, is, a, typic, colleg, student,, whose, ...
# 4      [befor, he, wa, sherlock’, rival,, moriarti, f...
# ...                                                  ...
# 70943  [thi, entri, current, doesn't, have, a, synops...
# 70944  [a, clumsi, girl, and, a, kind, boy, have, the...
# 70945  [thi, entri, current, doesn't, have, a, synops...
# 70946  [she', confess, 100, times,, what, happen, on,...
# 70947  [thi, entri, current, doesn't, have, a, synops...
#
# [70917 rows x 3 columns]

# %%
df.drop(["description"],axis=1,inplace=True)

# %%
df
# Out:
#                                                  title  \
# 0                   Salad Days (Tang LiuZang) - Part 2
# 1                              The Master of Diabolism
# 2      JoJo's Bizarre Adventure Part 7: Steel Ball Run
# 3                                  A Sign of Affection
# 4                                 Moriarty the Patriot
# ...                                                ...
# 70943                    Sonna ni Watashi wo Semenaide
# 70944                                Nakitsura ni Kiss
# 70945                                Renjou Lunch Time
# 70946                                101-kaime no Suki
# 70947                               Kirahoshi no Meril
#
#                                                     tags
# 0      [the, second, season, of, salad, day, (tang, l...
# 1      [as, the, grandmast, who, found, the, demon, s...
# 2      [set, in, 1890,, steel, ball, run, spotlight, ...
# 3      [yuki, is, a, typic, colleg, student,, whose, ...
# 4      [befor, he, wa, sherlock’, rival,, moriarti, f...
# ...                                                  ...
# 70943  [thi, entri, current, doesn't, have, a, synops...
# 70944  [a, clumsi, girl, and, a, kind, boy, have, the...
# 70945  [thi, entri, current, doesn't, have, a, synops...
# 70946  [she', confess, 100, times,, what, happen, on,...
# 70947  [thi, entri, current, doesn't, have, a, synops...
#
# [70917 rows x 2 columns]

# %%
df['tags']=df['tags'].apply(lambda x:' '.join(x))

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=10000,stop_words="english")

# %%
vector=cv.fit_transform(df['tags'])

# %%
model=NearestNeighbors(n_neighbors=10, metric='cosine')

# %%
model.fit(vector)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=10)

# %%
distance,indices=model.kneighbors(vector[2])

# %%
indices
# Out:
# array([[    2, 56120, 61575, 10634, 59038, 41019, 49548, 58592, 39040,
#         37293]])

# %%
df['title_lower'] = df['title'].str.lower()
def recommend(x):
    x_lower = x.lower()
    if x_lower not in df['title_lower'].values:
        print(f"'{x}' is not in the dataset.")
        return
    i=df[df['title_lower']==x_lower].index
    distance,indices=model.kneighbors(vector[i])
    print(f"similar comics to [{df.iloc[i]['title']}] are:")
    for j in indices[0]:
        if j!=i:
            print("recommended comic: ",df.iloc[j]['title'])
    print()

# %%
recommend('Tower of God - Part 2')
# Out:
# similar comics to [13    Tower of God - Part 2
# Name: title, dtype: object] are:
# recommended comic:  Tower of God - Part 3
# recommended comic:  Magician - Part 2
# recommended comic:  Raid - Part 2
# recommended comic:  Crepuscule (Yamchi) - Part 2
# recommended comic:  Dimensional Mercenary - Part 2
# recommended comic:  God of Blackfield - Part 2
# recommended comic:  Magician - Part 3
# recommended comic:  The Second Coming of Gluttony - Part 2
# recommended comic:  Sidekicks  - Part 2

# %%
recommend('Omniscient Reader')
# Out:
# similar comics to [9    Omniscient Reader
# Name: title, dtype: object] are:
# recommended comic:  Omniscient Reader (Novel)
# recommended comic:  Past Lives of the Thunder God
# recommended comic:  Stairs
# recommended comic:  The Fighting Monster
# recommended comic:  Shaman (Won-Pyo HONG)
# recommended comic:  Shi ni Modori, Subete wo Sukuu Tame ni Saikyou e to Itaru
# recommended comic:  I Become A Villain In My Novel
# recommended comic:  My Lady, Please Become My Heroine!
# recommended comic:  Ouroboros Record: Circus of Oubeniel (Light Novel)

# %%
i=input("Enter the name of manhwa or manga: ")
recommend(i)
# Out:
# Enter the name of manhwa or manga:  lover
# similar comics to [42306    Embrace My Dragoness
# Name: title, dtype: object] are:
# recommended comic:  M.T. Pass
# recommended comic:  Aru Hi, Knight ni Attanara
# recommended comic:  Shiawase Ikura de Kaemasu ka?
# recommended comic:  Special Relationship Law
# recommended comic:  Darkroom
# recommended comic:  I Can See Your Death
# recommended comic:  Minty Summer
# recommended comic:  Sorry I Couldn't Protect You!
# recommended comic:  Fruitless
